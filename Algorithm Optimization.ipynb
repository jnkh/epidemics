# %%
from graph_reciprocity import *
from nonlinear_selection import *
from graph_epidemic import *
# %load_ext autoreload
# %autoreload 2

# %%
n_n = 10
c_r = 0.5
N = 100
beta = 4.0/(c_r*n_n)
alpha = (N*beta)/n_n

k_sparse = 4.0
k = N-1
print N,alpha,beta
print (beta/alpha - 1.0/k_sparse)/(1 - 1.0/k_sparse)

y_n, y_minus,y_plus,y_p,critical_determinant = get_parameters(N,alpha,beta)
# Out:
# 100 8.0 0.8
# -0.2
# y_n = 0.1, y_- = 0.0146446609407, y_+ = 0.0853553390593, y_p = 0.11123724357, critical determinant = 0.5
# n_n = 10.0

# %%
#%pylab inline
plot_schematic(n_n,c_r,N,k_sparse)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# 100 8.0 0.8
# y_n = 0.1, y_- = 0.0146446609407, y_+ = 0.0853553390593, y_p = 0.11123724357, critical determinant = 0.5
# n_n = 10.0
# WARNING: pylab import has clobbered these variables: ['plotting', 'beta']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
k = N- 1
k_sparse = 4.0
num_trials_well_mixed = 200
num_trials = 5
regular = True
plotting = False
epidemic_sizes,fixed = run_epidemics(N,alpha,beta,num_trials=num_trials_well_mixed,plotting=plotting)
epidemic_sizes_g, fixed_g = run_epidemics(N,alpha,beta,num_trials=num_trials,plotting=plotting,\
                                       trajectory_fn = lambda a,b,c: simulate_graph_trajectory_adaptive(a,b,c,k=k,regular= regular))
# #epidemic_sizes_g2, fixed_g2 = run_epidemics(N,alpha,beta,num_trials=num_trials,plotting=1,\
#                                       trajectory_fn = lambda a,b,c: simulate_graph_trajectory_adaptive(a,b,c,k=k/2.0))
epidemic_sizes_g5, fixed_g5 = run_epidemics(N,alpha,beta,num_trials=num_trials,plotting=plotting,\
                                      trajectory_fn = lambda a,b,c: simulate_graph_trajectory_adaptive(a,b,c,k=k_sparse,regular=regular))

#print (1.0/N)/y_p
print P_fix(1.0/N,alpha,beta,N)
# Out:
# y_n = 0.01, y_- = 0.00146446609407, y_+ = 0.00853553390593, y_p = 0.011123724357, critical determinant = 0.5
# n_n = 10.0
# T_ave = 0.88295260279, P_fix = 0.01
# y_n = 0.01, y_- = 0.00146446609407, y_+ = 0.00853553390593, y_p = 0.011123724357, critical determinant = 0.5
# n_n = 10.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-27eb7646c104> in <module>()
#       6 plotting = False
#       7 epidemic_sizes,fixed = run_epidemics(N,alpha,beta,num_trials=num_trials_well_mixed,plotting=plotting)
# ----> 8 epidemic_sizes_g, fixed_g = run_epidemics(N,alpha,beta,num_trials=num_trials,plotting=plotting,                                       trajectory_fn = lambda a,b,c: simulate_graph_trajectory_adaptive(a,b,c,k=k,regular= regular))
#       9 # #epidemic_sizes_g2, fixed_g2 = run_epidemics(N,alpha,beta,num_trials=num_trials,plotting=1,\
#      10 #                                       trajectory_fn = lambda a,b,c: simulate_graph_trajectory_adaptive(a,b,c,k=k/2.0))
#
# /mnt/windows/D/Harvard/research/desai/population/src/nonlinear_selection.py in run_epidemics(N, alpha, beta, num_trials, plotting, trajectory_fn)
#      52     epidemic_size = np.zeros(num_trials)
#      53     for i in range(num_trials):
# ---> 54         ns,ts = trajectory_fn(N,alpha,beta)
#      55         fixed[i] = ns[-1] >= N
#      56         epidemic_size[i] = get_epidemic_size(ns,ts)
#
# <ipython-input-27-27eb7646c104> in <lambda>(a, b, c)
#       6 plotting = False
#       7 epidemic_sizes,fixed = run_epidemics(N,alpha,beta,num_trials=num_trials_well_mixed,plotting=plotting)
# ----> 8 epidemic_sizes_g, fixed_g = run_epidemics(N,alpha,beta,num_trials=num_trials,plotting=plotting,                                       trajectory_fn = lambda a,b,c: simulate_graph_trajectory_adaptive(a,b,c,k=k,regular= regular))
#       9 # #epidemic_sizes_g2, fixed_g2 = run_epidemics(N,alpha,beta,num_trials=num_trials,plotting=1,\
#      10 #                                       trajectory_fn = lambda a,b,c: simulate_graph_trajectory_adaptive(a,b,c,k=k/2.0))
#
# /mnt/windows/D/Harvard/research/desai/population/src/graph_epidemic.pyc in simulate_graph_trajectory_adaptive(N, alpha, beta, plotting, k, regular)
#     129     ts = [0]
#     130     p_edge = 1.0*k/(N-1)
# --> 131     G = create_graph(N,p_edge,ns[0],regular)
#     132     print len(sorted(nx.connected_components(G),key=len,reverse=True)[0])
#     133
#
# /mnt/windows/D/Harvard/research/desai/population/src/graph_epidemic.pyc in create_graph(N_nodes, p_edge, n_infected, regular)
#      20     if regular:
#      21         k = int(round(p_edge*(N_nodes-1)))
# ---> 22         G = nx.random_regular_graph(k,N_nodes)
#      23     else:
#      24         G = nx.gnp_random_graph(N_nodes,p_edge,directed=False)
#
# /home/julian/Apps/epd-7.3-1/lib/python2.7/site-packages/networkx/generators/random_graphs.pyc in random_regular_graph(d, n, seed)
#     549     # the generation of such a set is not guaranteed.
#     550     # Try repeatedly to find one.
# --> 551     edges = _try_creation()
#     552     while edges is None:
#     553         edges = _try_creation()
#
# /home/julian/Apps/epd-7.3-1/lib/python2.7/site-packages/networkx/generators/random_graphs.pyc in _try_creation()
#     528         while stubs:
#     529             potential_edges = defaultdict(lambda: 0)
# --> 530             random.shuffle(stubs)
#     531             stubiter = iter(stubs)
#     532             for s1, s2 in zip(stubiter, stubiter):
#
# /home/julian/Apps/epd-7.3-1/lib/python2.7/random.pyc in shuffle(self, x, random, int)
#     285         for i in reversed(xrange(1, len(x))):
#     286             # pick an element in x[:i+1] with which to exchange x[i]
# --> 287             j = int(random() * (i+1))
#     288             x[i], x[j] = x[j], x[i]
#     289
#
# KeyboardInterrupt:

# %%
e_sizes = epidemic_sizes
fixed_curr = fixed

#close(1)
figure(3)
hold(1)
nbins = 40
bins = np.logspace(0,log10(max(e_sizes[fixed_curr == 0])),nbins)
hist(e_sizes[fixed_curr == 0],log=True,bins=bins,alpha=0.4,normed=True,label='simulation')
xlabel('$w$',size=20)
ylabel('$P(w)$',size=20)
gca().set_xscale('log')
w_range = np.logspace(0,log10(max(e_sizes[fixed_curr == 0])))
P_w_th_range = P_w_th(w_range,s(sqrt(w_range)/N,alpha,beta))
#P_w_th_range_eff = P_w_th(w_range,get_s_eff(sqrt(w_range)/N,alpha,beta,k_sparse))

def normed_distribution(x,px):
    return px/sum(diff(x)*px[:-1])


#normed = integrate.quad(lambda x: P_w_th(x,0),min(epidemic_sizes[fixed_curr==0]),max(epidemic_sizes[fixed_curr==0]))[0]
plot(w_range,normed_distribution(w_range,P_w_th_range),'-r',label=r'theory')#$P(w) \sim e^{- s(\sqrt{w})^2 w/4} w^{-3/2}/(1 + s(\sqrt{w}))$ (theory)')
plot(w_range,normed_distribution(w_range,P_w_th_range_eff),'-g',label=r'effective theory')#$P(w) \sim e^{- s(\sqrt{w})^2 w/4} w^{-3/2}/(1 + s(\sqrt{w}))$ (theory)')

#plot(w_range,s(sqrt(w_range)/N,alpha,beta)**2*w_range/4.0,label=r'$s(\sqrt{w})^2 w /4$')
axvline((2*y_p*N)**2,color = 'k',label=r'$w=4(y_p N)^2$')
axvline((2*y_n*N)**2,color = 'k',label=r'$w=4(y_n N)^2$',linestyle='--')
grid()
if (y_minus > 0):
    axvline((2*y_minus*N)**2,color = 'r',label=r'$w=4(y_- N)^2$')
#legend(prop={'size':15},loc='lower right')

# %%
# %load_ext line_profiler

# %%
# %lprun -f update_graph run_epidemics(N,alpha,beta,num_trials=num_trials,plotting=plotting,\
                                       trajectory_fn = lambda a,b,c: simulate_graph_trajectory_adaptive(a,b,c,k=k,regular= regular))
# Out:
# y_n = 0.1, y_- = 0.0146446609407, y_+ = 0.0853553390593, y_p = 0.11123724357, critical determinant = 0.5
# n_n = 10.0
# 100
# 100
# 100
# 100
# 100
# T_ave = 0.74, P_fix = 0.0
